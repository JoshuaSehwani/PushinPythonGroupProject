# %%
#Here is where we can add our data and work to create clean dataframes using panda
#I-(Josh) will be working to add the car sales data as best as I can

# %%
import pandas as pd
import numpy as np
import requests as rq
from sklearn.preprocessing import OneHotEncoder
from zipfile import ZipFile

# %%
carSales_df = pd.read_csv('./sale/Online_Cars_Sale_Marketplace.csv')

# %%
type(carSales_df)
# Out:
# pandas.core.frame.DataFrame

# %%
carSales_df
# Out:
#       Year     Make                   Model Used/New    Price  ConsumerRating  \
# 0     2019   Toyota               Sienna SE     Used  $39,998             4.6
# 1     2018     Ford            F-150 Lariat     Used  $49,985             4.8
# 2     2017      RAM            1500 Laramie     Used  $41,860             4.7
# 3     2021    Honda         Accord Sport SE     Used  $28,500             5.0
# 4     2020    Lexus                  RX 350     Used  $49,000             4.8
# ...    ...      ...                     ...      ...      ...             ...
# 9374  2019   Subaru  Crosstrek 2.0i Premium     Used  $27,374             4.7
# 9375  2019     Audi         Q8 3.0T Premium     Used  $61,998             4.8
# 9376  2017    Buick         Enclave Leather     Used  $26,944             4.8
# 9377  2019   Subaru        Forester Premium     Used  $28,568             4.7
# 9378  2019  Hyundai   Santa Fe Ultimate 2.4     Used  $32,091             4.8
#
# ...

# %%
carSales_df.head(20)
# Out:
#     Year           Make                      Model         Used/New    Price  \
# 0   2019         Toyota                  Sienna SE             Used  $39,998
# 1   2018           Ford               F-150 Lariat             Used  $49,985
# 2   2017            RAM               1500 Laramie             Used  $41,860
# 3   2021          Honda            Accord Sport SE             Used  $28,500
# 4   2020          Lexus                     RX 350             Used  $49,000
# 5   2012         Toyota                4Runner SR5             Used  $23,541
# 6   2017          Honda                    HR-V LX             Used  $20,995
# 7   2014  Mercedes-Benz              E-Class E 350             Used  $18,985
# 8   2021          Honda  Pilot Touring 8-Passenger             Used  $44,299
# 9   2020          Dodge          Charger Scat Pack  Dodge Certified  $46,773
# 10  2017          Lexus                RC 350 Base             Used  $42,734
# ...

# %%
carSales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9379 entries, 0 to 9378
# Data columns (total 32 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   9379 non-null   int64
#  1   Make                   9379 non-null   object
#  2   Model                  9379 non-null   object
#  3   Used/New               9379 non-null   object
#  4   Price                  9379 non-null   object
#  5   ConsumerRating         9379 non-null   float64
#  6   ConsumerReviews        9379 non-null   int64
#  7   SellerType             9379 non-null   object
#  8   SellerName             9379 non-null   object
#  9   SellerRating           9379 non-null   float64
#  10  SellerReviews          9379 non-null   int64
#  11  StreetName             9379 non-null   object
#  12  State                  9379 non-null   object
#  13  Zipcode                9379 non-null   object
# ...

# %%
carSales_df.describe()
# Out:
#               Year  ConsumerRating  ConsumerReviews  SellerRating  \
# count  9379.000000     9379.000000      9379.000000   9379.000000
# mean   2018.721719        4.702825       133.187014      4.412571
# std       2.221708        0.240795       154.985640      0.626258
# min    2001.000000        2.500000         1.000000      1.000000
# 25%    2018.000000        4.700000        30.000000      4.300000
# 50%    2019.000000        4.800000        75.000000      4.600000
# 75%    2020.000000        4.800000       182.000000      4.800000
# max    2022.000000        5.000000       817.000000      5.000000
#
#        SellerReviews  ComfortRating  InteriorDesignRating  PerformanceRating  \
# count    9379.000000    9379.000000           9379.000000        9379.000000
# mean      984.089988       4.771895              4.727391           4.696290
# std      1609.039864       0.217822              0.194391           0.253664
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.plot(carSales_df["Price"], carSales_df["Year"], marker="v")
plt.show()

# %%
carSales_df.shape
# Out:
# (9379, 32)

# %%
carSales_df.dtypes
# Out:
# Year                       int64
# Make                      object
# Model                     object
# Used/New                  object
# Price                     object
# ConsumerRating           float64
# ConsumerReviews            int64
# SellerType                object
# SellerName                object
# SellerRating             float64
# SellerReviews              int64
# StreetName                object
# State                     object
# Zipcode                   object
# DealType                  object
# ComfortRating            float64
# InteriorDesignRating     float64
# PerformanceRating        float64
# ValueForMoneyRating      float64
# ExteriorStylingRating    float64
# ReliabilityRating        float64
# ExteriorColor             object
# InteriorColor             object
# Drivetrain                object
# MinMPG                     int64
# MaxMPG                     int64
# FuelType                  object
# Transmission              object
# ...

# %%
carSales_df.hist(column='Mileage')
# Out:
# array([[<AxesSubplot:title={'center':'Mileage'}>]], dtype=object)

# %%
carSales_df.hist(column='Year')
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>]], dtype=object)

# %%
carSales_df.hist(column='ConsumerRating')
# Out:
# array([[<AxesSubplot:title={'center':'ConsumerRating'}>]], dtype=object)

# %%
###carSales_df['ExteriorColor'] = carSales_df['ExteriorColor'].astype('bool')
carSales_df['Price'] = carSales_df['ExteriorColor'].astype('object')
carSales_df['ExteriorColor'] = carSales_df['ExteriorColor'].astype('object')
carSales_df.dtypes
# Out:
# Year                       int64
# Make                      object
# Model                     object
# Used/New                  object
# Price                     object
# ConsumerRating           float64
# ConsumerReviews            int64
# SellerType                object
# SellerName                object
# SellerRating             float64
# SellerReviews              int64
# StreetName                object
# State                     object
# Zipcode                   object
# DealType                  object
# ComfortRating            float64
# InteriorDesignRating     float64
# PerformanceRating        float64
# ValueForMoneyRating      float64
# ExteriorStylingRating    float64
# ReliabilityRating        float64
# ExteriorColor             object
# InteriorColor             object
# Drivetrain                object
# MinMPG                     int64
# MaxMPG                     int64
# FuelType                  object
# Transmission              object
# ...

# %%
carSales_df.hist(column='ExteriorColor')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/73/4z9gjppn68lbcx5zcxj8yrmc0000gn/T/ipykernel_1250/1405915222.py in <module>
# ----> 1 carSales_df.hist(column='ExteriorColor')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     224     """
#     225     plot_backend = _get_plot_backend(backend)
# --> 226     return plot_backend.hist_frame(
#     227         data,
#     228         column=column,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     478
#     479     if naxes == 0:
# --> 480         raise ValueError(
# ...
